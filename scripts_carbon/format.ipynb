# %% [markdown]
# # Format
# > By Gati Aher
# > Sept 17, 2021
#
# **Dataset:** FCF Carbon Perturbation (Cellulose-Glucose-Malate)
#
# **Goal:** Put raw data in more workable format for downstream analysis

# %% [markdown]
# ## Outputs
#
# * `data/raw/carbon/processed_feature_metadata.tsv`
# * `data/raw/carbon/processed_OTU_counts.tsv`
# * `data/raw/carbon/processed_sample_metadata.tsv`
# * `data/raw/carbon/processed_taxonomy_table.tsv`
# * `data/raw/carbon/processed_taxonomy.tsv`
# * `data/raw/carbon/renamed_081616JHnew515Fcomplete-pr.fasta.otus.fa`

# %%
raw_location = "../data/raw/carbon"

# %%
# imports
import skbio
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ## Load Raw Data
#
# Inputs:
# * Sample ID: Sample Name
#     * (Jean): `sample_names.csv`
# * Sample Name x Meta Information
#     * (Jean): `carbon_annotations.csv`
# * OTU ID-Taxonomy x Sample Name x OTU Counts
#     * (MR DNA): `081616JHnew515Fcomplete-pr.fasta.otus.fa.OTU.txt`

# %%
# get map of MR DNA sample IDs to sample names
sample_names = pd.read_csv(f"{raw_location}/sample_names.csv", index_col=0)
# prefix sample names with s (so they do not start with a number) 
sample_names['key'] = 's' + sample_names['key'].astype(str)

sample_names
# Out:
#            key
# name
# Olin1     sC0C
# Olin2   s1C03A
# Olin3   s1C03B
# Olin4   s1G03A
# Olin5   s1G03B
# ...        ...
# Olin84  s3G10A
# Olin85  s3G10B
# Olin86  s3G10C
# Olin87  s2M10A
# Olin88  s2M10C
#
# [88 rows x 1 columns]

# %%
# get map of sample IDs to decided cluster
sample_clusters = pd.read_csv("../data/processed_carbon_53OTUs/cluster_decisions.csv", index_col=0)
sample_clusters = sample_clusters.rename(columns={"x": "cluster"})
sample_clusters
# Out:
#        cluster
# s3M07C    late
# s3M05B    late
# s3M07A    late
# s3M05A    late
# s3M05C    late
# ...        ...
# s2M10B     mid
# s2C03A     mid
# s2C03B     mid
# s2C05A     mid
# s2C05B     mid
#
# [62 rows x 1 columns]

# %%
# get table of sample names to sample meta data
sample_annotations_from_file = pd.read_csv(f"{raw_location}/carbon_annotations.csv", index_col=0) # these aren't in the right order
sample_annotations_from_file
# Out:
#       series       food  day
# C0C       C0  cellulose   10
# 1C03A     1C  cellulose    3
# 1C03B     1C  cellulose    3
# 1C05A     1C  cellulose    5
# 1C05B     1C  cellulose    5
# ...      ...        ...  ...
# 3G07A     3G  cellulose    7
# 3G07B     3G  cellulose    7
# 3G07C     3G  cellulose    7
# 3G10A     3G  cellulose   10
# 3G10B     3G  cellulose   10
#
# [87 rows x 3 columns]

# %%
# get table of OTU ID-taxonomy x absolute OTU counts
otu_raw = pd.read_csv(f"{raw_location}/081616JHnew515Fcomplete-pr.fasta.otus.fa.OTU.txt", sep="\t", index_col=0)
otu_raw.index.names = ['featureID']
otu_raw.head()
# Out:
#                                                       16rRNA  \
# featureID
# OTU_1      eu528231.1 seasonal dynamics mudflat mouth maj...
# OTU_2      uncultured opitutus sp. ;k__bacteria;p__verruc...
# OTU_3      rhodopseudomonas palustris ;k__bacteria;p__pro...
# OTU_4      ay297802.1 waterlogged archaeological wood clo...
# OTU_5      rhodoblastus acidophilus ;k__bacteria;p__prote...
#
#            Percent Homology  evalue    bitscore  \
# featureID
# OTU_1            100.000000     0.0  711.813612
# OTU_2             96.969697     0.0  661.319285
# OTU_3             99.493671     0.0  704.600137
# OTU_4             99.492386     0.0  702.796768
# OTU_5             99.746835     0.0  708.206874
#
#            homology extract gibbsfree_otu/gibbsfree_homolog  \
# featureID
# OTU_1                                                   NaN
# OTU_2                                                   NaN
# OTU_3                                                   NaN
# OTU_4                                                   NaN
# OTU_5                                                   NaN
#
#            total length gibbsfree_otu/otu_lenth/gibbsfree_homolog/homolog_length  \
# featureID
# OTU_1                                                    NaN
# OTU_2                                                    NaN
# OTU_3                                                    NaN
# OTU_4                                                    NaN
# OTU_5                                                    NaN
#
#            Olin1  Olin2  Olin3  Olin4  ...  Olin80  Olin81  Olin82  Olin83  \
# featureID                              ...
# OTU_1          6     11     13     20  ...      11      19      25      22
# OTU_2      17546  18302  32674   9700  ...   31216   17838   12257   19679
# OTU_3       3169   3033   4495   3455  ...    1073    4207    1275    2274
# OTU_4       5243   3526   4658  29020  ...   17928   19104   11308   11368
# OTU_5       3809   1128   1313   1001  ...   17129   22577    7156   26149
#
#            Olin84  Olin85  Olin86  Olin87  Olin88  Unnamed: 95
# featureID
# OTU_1          16      16       6       5       4          NaN
# OTU_2       16779   15614    2107   42046   56298          NaN
# OTU_3        4900    2027    1140    3192    2086          NaN
# OTU_4       26958   15939    3121   30080   23869          NaN
# OTU_5        9243    2211    1368   13865    5190          NaN
#
# [5 rows x 95 columns]

# %% [markdown]
# ## Process Data
#
# Outputs:
# * Sample Name x Meta Information
#     * `processed_sample_metadata.tsv`
# * OTU ID x Sample ID x HTS Counts
#     * `processed_OTU_counts.tsv`
# * OTU ID x Taxonomy
#     * `processed_taxonomy.tsv`

# %% [markdown]
# ### Create `sample_metadata.tsv`

# %%
# format useful sample annotations file
# columns: index series carbon transfer day

ann_index = []
ann_series = []
ann_carbon = []
ann_numerical_transfer = []
ann_transfer = []
ann_day = []
ann_replicate = []

for sn in sample_annotations_from_file.index:
    # index
    ann_index.append("s" + sn)
    # series
    if sn == "C0C":
        ann_series.append("C0C")
    else:
        ann_series.append(sn[1])
    # carbon
    if sn == "C0C":
        ann_carbon.append("original")
    elif sample_annotations_from_file.loc[sn, "food"] == "cellulose":
        ann_carbon.append("cellulose")
    elif sample_annotations_from_file.loc[sn, "food"] == "glucose":
        ann_carbon.append("glucose")
    elif sample_annotations_from_file.loc[sn, "food"] == "malate":
        ann_carbon.append("malate")
    else:
        ann_carbon.append("X")
    # numerical transfer
    if sn == "C0C":
        ann_numerical_transfer.append(0)
    else:
        ann_numerical_transfer.append(int(sn[0]))
    # transfer
    if sn == "C0C":
        ann_transfer.append("C0C")
    else:
        ann_transfer.append(sn[0:2])
    # day
    if sn == "C0C":
        ann_day.append(10)
    else:
        ann_day.append(int(sn[2:-1]))
    # replicate
    if sn == "C0C":
        ann_replicate.append("C0C")
    else:
        ann_replicate.append(sn[-1])  
        
# print("ann_group", ann_group)
# print("ann_series", ann_series)
# print("ann_carbon", ann_carbon)
# print("ann_transfer", ann_transfer)
# print("ann_day", ann_day)
# print("ann_replicate", ann_replicate)
# print("ann_index", ann_index)

sample_metadata = pd.DataFrame()
sample_metadata["series"] = ann_series
sample_metadata["carbon"] = ann_carbon
sample_metadata["numerical_transfer"] = ann_numerical_transfer
sample_metadata["transfer"] = ann_transfer
sample_metadata["day"] = ann_day
sample_metadata["replicate"] = ann_replicate
sample_metadata["sampleID"] = ann_index
sample_metadata = sample_metadata.set_index("sampleID")

print("samples:", list(sample_metadata.transfer))
sample_metadata = sample_metadata.drop(["s2M07C"])
print("sample_metadata.shape", sample_metadata.shape)
# Out:
# samples: ['C0C', '1C', '1C', '1C', '1C', '1C', '1C', '1C', '1C', '1C', '1C', '2C', '2C', '2C', '2C', '2C', '2C', '1M', '1M', '1M', '1M', '1M', '1M', '1M', '1M', '1M', '1M', '1M', '1M', '2M', '2M', '2M', '2M', '2M', '2M', '2M', '2M', '2M', '2M', '2M', '3M', '3M', '3M', '3M', '3M', '3M', '3M', '3M', '3M', '3M', '3M', '3M', '1G', '1G', '1G', '1G', '1G', '1G', '1G', '1G', '1G', '1G', '1G', '1G', '2G', '2G', '2G', '2G', '2G', '2G', '2G', '2G', '2G', '2G', '2G', '2G', '3G', '3G', '3G', '3G', '3G', '3G', '3G', '3G', '3G', '3G', '3G']
# sample_metadata.shape (86, 6)

# %%
type(sample_metadata["day"][1])
# Out:
# numpy.int64

# %% [markdown]
# ## Add sample clusters (growth phase) to sample metadata

# %%
sample_metadata = sample_metadata.merge(sample_clusters, left_index=True, right_index=True, how="left")
sample_metadata
# Out:
#          series     carbon  numerical_transfer transfer  day replicate cluster
# sampleID
# sC0C        C0C   original                   0      C0C   10       C0C    late
# s1C03A        C  cellulose                   1       1C    3         A    late
# s1C03B        C  cellulose                   1       1C    3         B    late
# s1C05A        C  cellulose                   1       1C    5         A     mid
# s1C05B        C  cellulose                   1       1C    5         B    late
# ...         ...        ...                 ...      ...  ...       ...     ...
# s3G07A        G  cellulose                   3       3G    7         A    late
# s3G07B        G  cellulose                   3       3G    7         B    late
# s3G07C        G  cellulose                   3       3G    7         C    late
# s3G10A        G  cellulose                   3       3G   10         A    late
# s3G10B        G  cellulose                   3       3G   10         B    late
#
# [86 rows x 7 columns]

# %%
# fill in other clusters
def sample_cluster(row):
    if (row["transfer"] == "1M"): return "perturbed"
    if (row["transfer"] == "1G"): return "perturbed"
    # manual examination showed that these are different than mid
    if (row["transfer"] in ["1C", "2G", "2M"] 
        and row["day"] == 3): 
        return "early"
    # manual examination showed that this is objectively wrong
    if (row["transfer"] in ["1C", "2G", "2M"] and 
        row["day"] == 5 and 
        row["cluster"] == "late"): 
        return "early"
    # manual examination showed that this is objectively wrong
    if (row.name in ["s2M05A", "s2M05B"]): 
        return "early"
    return row["cluster"]

sample_metadata["cluster"] = sample_metadata.apply(lambda x: sample_cluster(x), axis=1)
sample_metadata
# Out:
#          series     carbon  numerical_transfer transfer  day replicate cluster
# sampleID
# sC0C        C0C   original                   0      C0C   10       C0C    late
# s1C03A        C  cellulose                   1       1C    3         A   early
# s1C03B        C  cellulose                   1       1C    3         B   early
# s1C05A        C  cellulose                   1       1C    5         A     mid
# s1C05B        C  cellulose                   1       1C    5         B   early
# ...         ...        ...                 ...      ...  ...       ...     ...
# s3G07A        G  cellulose                   3       3G    7         A    late
# s3G07B        G  cellulose                   3       3G    7         B    late
# s3G07C        G  cellulose                   3       3G    7         C    late
# s3G10A        G  cellulose                   3       3G   10         A    late
# s3G10B        G  cellulose                   3       3G   10         B    late
#
# [86 rows x 7 columns]

# %%
sample_metadata["cluster"].value_counts()
# Out:
# late         32
# perturbed    24
# mid          19
# early        11
# Name: cluster, dtype: int64

# %%
# add more focused sample groups to sample metadata
def sample_group(row):
    if (row["cluster"] == "perturbed"):
        if (row["transfer"] == "1G"): return "perturbed G"
        if (row["transfer"] == "1M"): return "perturbed M"
    if (row["cluster"] == "mid"):
        if (row["series"] == "C"): return "mid C:C"
        if (row["series"] == "G"): return "mid G:C"
        if (row["series"] == "M"): return "mid M:C"
    if (row["cluster"] == "late"):
        if (row["series"] == "C"): return "late C:C"
        if (row["series"] == "C0C"): return "late C:C"
        if (row["series"] == "G"): return "late G:C"
        if (row["series"] == "M"): return "late M:C"
    return row["cluster"]

sample_metadata["growth phase"] = sample_metadata.apply(lambda x: sample_group(x), axis=1)
sample_metadata
# Out:
#          series     carbon  numerical_transfer transfer  day replicate  \
# sampleID
# sC0C        C0C   original                   0      C0C   10       C0C
# s1C03A        C  cellulose                   1       1C    3         A
# s1C03B        C  cellulose                   1       1C    3         B
# s1C05A        C  cellulose                   1       1C    5         A
# s1C05B        C  cellulose                   1       1C    5         B
# ...         ...        ...                 ...      ...  ...       ...
# s3G07A        G  cellulose                   3       3G    7         A
# s3G07B        G  cellulose                   3       3G    7         B
# s3G07C        G  cellulose                   3       3G    7         C
# s3G10A        G  cellulose                   3       3G   10         A
# s3G10B        G  cellulose                   3       3G   10         B
#
#          cluster growth phase
# sampleID
# sC0C        late     late C:C
# s1C03A     early        early
# s1C03B     early        early
# s1C05A       mid      mid C:C
# s1C05B     early        early
# ...          ...          ...
# s3G07A      late     late G:C
# s3G07B      late     late G:C
# s3G07C      late     late G:C
# s3G10A      late     late G:C
# s3G10B      late     late G:C
#
# [86 rows x 8 columns]

# %%
sample_metadata["growth phase"].value_counts()
# Out:
# late G:C       14
# perturbed G    12
# perturbed M    12
# early          11
# late M:C       11
# late C:C        7
# mid C:C         7
# mid G:C         6
# mid M:C         6
# Name: growth phase, dtype: int64

# %% [markdown]
# ### Create `OTU_counts.tsv`

# %%
# format table of OTU ID x sample name x absolute counts
OTU_counts = otu_raw.filter(regex='^Olin')
# rename sample ID to sample names
OTU_counts = OTU_counts.rename(columns=sample_names.to_dict()["key"])
# NOTE: 3G10C and 2M7C were removed because they were incorrectly sequenced
OTU_counts = OTU_counts.drop(columns=["s3G10C", "s2M07C"])
# order columns by order in sample metadata
OTU_counts = OTU_counts.reindex(columns=list(sample_metadata.index))

# %%
OTU_counts
# Out:
#             sC0C  s1C03A  s1C03B  s1C05A  s1C05B  s1C07A  s1C07B  s1C10A  \
# featureID
# OTU_1          6      11      13      30      15      23      25       5
# OTU_2      17546   18302   32674   15446   22216   25011   21224   13067
# OTU_3       3169    3033    4495    3138    4601    3633    1919    2952
# OTU_4       5243    3526    4658    2475    5861    5526    3808    4545
# OTU_5       3809    1128    1313    1989    3024    2419    1540    1956
# ...          ...     ...     ...     ...     ...     ...     ...     ...
# OTU_639        1       0       0       1       1       0       0       0
# OTU_640     4270    2662    3657    2136    4412    2622    1964    2673
# OTU_641        0       0       0       1       3       3       0       5
# OTU_642        0       0       0       0       0       0       0       0
# OTU_643        0       0       0       0       0       0       0       0
#
#            s1C10B  s1C20A  ...  s3G03B  s3G03C  s3G05A  s3G05B  s3G05C  \
# featureID                  ...
# OTU_1           8       0  ...      30      46       1      14      10
# OTU_2       13340    6896  ...    6869    8322    9792   21106   39348
# OTU_3        2110    5739  ...     610     599     993    2016    1433
# OTU_4        4121    4551  ...    7179    6226   10400   21570   21360
# OTU_5         869    2546  ...     923    1287    2062    3568    2621
# ...           ...     ...  ...     ...     ...     ...     ...     ...
# OTU_639         1       2  ...       0       0       0       0       0
# OTU_640      1856    4256  ...     312     248     302     535     498
# OTU_641         0       0  ...       0       3       1       3       0
# OTU_642         0       0  ...       0       0       0       0       0
# OTU_643         0       1  ...       0       0       0       0       0
#
#            s3G07A  s3G07B  s3G07C  s3G10A  s3G10B
# featureID
# OTU_1           6       3       1      16      16
# OTU_2       24470   34872   33561   16779   15614
# OTU_3        3008    1979    2067    4900    2027
# OTU_4       27375   29348   27454   26958   15939
# OTU_5        7346    3789    4428    9243    2211
# ...           ...     ...     ...     ...     ...
# OTU_639         0       0       0       0       0
# OTU_640       755     607     602    1442     684
# OTU_641         9       4       6       4       1
# OTU_642         0       0       0       0       0
# OTU_643         0       0       0       0       0
#
# [643 rows x 86 columns]

# %% [markdown]
# ### Create `feature_metadata.tsv`

# %%
# format table of OTU ID x taxonomy & function
feature_metadata = pd.DataFrame(index=otu_raw.index, columns=["Name"])

for otu, desc in otu_raw.iterrows(): 
    parts = desc["16rRNA"].split(";")
    taxonomy = "Unassigned"
    for i, part in enumerate(parts):
        if i == 0:
            feature_metadata.loc[otu, "Name"] = part
        elif part.startswith("k__"):
            feature_metadata.loc[otu, "kingdom"] = part[3:].capitalize()
            taxonomy = "Root;" + part + ";"
        elif part.startswith("p__"):
            feature_metadata.loc[otu, "phylum"] = part[3:].capitalize()
            taxonomy += part + ";"
        elif part.startswith("c__"):
            feature_metadata.loc[otu, "class"] = part[3:].capitalize()
            taxonomy += part + ";"
        elif part.startswith("o__"):
            feature_metadata.loc[otu, "order"] = part[3:].capitalize()
            taxonomy += part + ";"
        elif part.startswith("f__"):
            feature_metadata.loc[otu, "family"] = part[3:].capitalize()
            taxonomy += part + ";"
        elif part.startswith("g__"):
            feature_metadata.loc[otu, "genus"] = part[3:].capitalize()
            taxonomy += part + ";"
        elif part.startswith("s__"):
            feature_metadata.loc[otu, "species"] = part[3:]
            taxonomy += part + ";"
        elif part.startswith("superkingdom__"):
            feature_metadata.loc[otu, "superkingdom"] = part[14:]
        elif part.startswith("superphylum__"):
            feature_metadata.loc[otu, "superphylum"] = part[13:]
        elif part.startswith("subclass"):
            feature_metadata.loc[otu, "subclass"] = part[8:]
        elif part.startswith("suborder"):
            feature_metadata.loc[otu, "suborder"] = part[8:]
        elif part.startswith("subphylum__"):
            feature_metadata.loc[otu, "subphylum"] = part[9:]
        else:
            print("OTU:", otu, "Extra PART:", part)
            
    feature_metadata.loc[otu, "taxonomy"] = taxonomy
    feature_metadata.fillna("Unassigned", inplace=True)
# Out:
# OTU: OTU_18 Extra PART: species group  pseudomonas fluorescens group
# OTU: OTU_526 Extra PART: jpl_saf&apos
# OTU: OTU_526 Extra PART:  during msl mission spacecraft assembly clean room floor clone gi8_sp_i21

# %%
feature_metadata
# Out:
#                                                         Name        kingdom  \
# featureID
# OTU_1      eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_2                               uncultured opitutus sp.        Bacteria
# OTU_3                            rhodopseudomonas palustris        Bacteria
# OTU_4      ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_5                              rhodoblastus acidophilus        Bacteria
# OTU_6      eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_7      af025373.1 citrobacter werkmanii str. cdc 0876...       Bacteria
# OTU_8                            uncultured bacteroides sp.        Bacteria
# OTU_9                      eubacterium sp. oral clone ji012        Bacteria
# OTU_10                           uncultured pontibacter sp.        Bacteria
# OTU_11                           uncultured acetobacter sp.        Bacteria
# OTU_12                         paludibacter propionicigenes        Bacteria
# OTU_13                           uncultured bacteroides sp.        Bacteria
# OTU_14                       uncultured ancalomicrobium sp.        Bacteria
# OTU_15                           uncultured spirochaeta sp.        Bacteria
# OTU_16     cu927348.1 towards definition core microorgani...       Bacteria
# OTU_17                           cloacibacterium normanense        Bacteria
# OTU_18           ay267192.1 pseudomonas veronii str. 16_6a         Bacteria
# OTU_19        fj154804.1 streptococcus salivarius str. k12         Bacteria
# OTU_20                           propionicimonas paludicola        Bacteria
# OTU_21                      uncultured stenotrophomonas sp.        Bacteria
# OTU_22                          uncultured ruminococcus sp.        Bacteria
# OTU_23               ab079679.1 rhodopseudomonas sp. hmd89         Bacteria
# OTU_24               ab079679.1 rhodopseudomonas sp. hmd89         Bacteria
# OTU_25                              azospirillum amazonense        Bacteria
# OTU_26              fj596644.1 acinetobacter junii str. p1         Bacteria
# OTU_27                       uncultured ancalomicrobium sp.        Bacteria
# OTU_28                      uncultured rhodopseudomonas sp.        Bacteria
# OTU_29                                dechloromonas agitata        Bacteria
# OTU_30                           uncultured bacteroides sp.        Bacteria
# OTU_31            zoogloea sp. enrichment culture clone m_1        Bacteria
# OTU_32     gq046324.1 topographical and temporal human sk...       Bacteria
# OTU_33                            uncultured acidovorax sp.        Bacteria
# OTU_34                d25313.1 rhodoplanes roseus str. 941         Bacteria
# OTU_35                           uncultured acetobacter sp.        Bacteria
# OTU_36                                 pontibacter salisaro        Bacteria
# OTU_37                    barnesiella viscericola dsm 18177        Bacteria
# OTU_38               dq414679.1 achromobacter xylosoxidans         Bacteria
# OTU_39                           pleomorphomonas sp. r5_392        Bacteria
# OTU_40          opitutus sp. enrichment culture clone lt_b7        Bacteria
# OTU_41     ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_42                       uncultured ancalomicrobium sp.        Bacteria
# OTU_43     aj582755.1 desulfovibrio ferrireducens str. cy1         Bacteria
# OTU_44                      uncultured rhodopseudomonas sp.        Bacteria
# OTU_45                           uncultured bacteroides sp.        Bacteria
# OTU_46                           uncultured acetobacter sp.        Bacteria
# OTU_47                           uncultured bacteroides sp.        Bacteria
# OTU_48                           uncultured bacteroides sp.        Bacteria
# OTU_49                           uncultured bacteroides sp.        Bacteria
# OTU_50                              rhizobium straminoryzae        Bacteria
# OTU_51                           uncultured pontibacter sp.        Bacteria
# OTU_52     eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_53     fj540915.1 bradyrhizobium yuanmingense str. dt...       Bacteria
# OTU_54                              phaeospirillum sp. ak32        Bacteria
# OTU_55                          uncultured methanosaeta sp.         Archaea
# OTU_56                           uncultured bacteroides sp.        Bacteria
# OTU_57     af529115.1 trichloroethene_contaminated site c...       Bacteria
# OTU_58                              uncultured opitutus sp.        Bacteria
# OTU_59                                 pontibacter sp. swu8        Bacteria
# OTU_60                           pleomorphomonas sp. r5_392        Bacteria
# OTU_61     ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_62                                 pontibacter sp. nrtx        Bacteria
# OTU_63               ab079679.1 rhodopseudomonas sp. hmd89         Bacteria
# OTU_64           aj563927.1 methylocella palustris str. h4         Bacteria
# OTU_65                           uncultured fibrobacter sp.        Bacteria
# OTU_66           eu183233.1 sphingobium yanoikuyae str. xj         Bacteria
# OTU_67     eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_68     eu767784.1 pervasive effects antibiotic on hum...       Bacteria
# OTU_69                              uncultured opitutus sp.        Bacteria
# OTU_70                          uncultured enterobacter sp.        Bacteria
# OTU_71                             rhodoblastus acidophilus        Bacteria
# OTU_72                              phaeospirillum sp. ak32        Bacteria
# OTU_73     eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_74                           uncultured bacteroides sp.        Bacteria
# OTU_75     ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_76                           uncultured acetobacter sp.        Bacteria
# OTU_77     am947938.1 rhodopseudomonas pangongensis str. ...       Bacteria
# OTU_78       aj318524.1 rhodovibrio sodomensis str. sg3105         Bacteria
# OTU_79                           uncultured bacteroides sp.        Bacteria
# OTU_80                           uncultured bacteroides sp.        Bacteria
# OTU_81                               rhizobium petrolearium        Bacteria
# OTU_82                           uncultured bacteroides sp.        Bacteria
# OTU_83                           uncultured bacteroides sp.        Bacteria
# OTU_84     ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_85                          uncultured rhodothermus sp.        Bacteria
# OTU_86                            uncultured chlorobium sp.        Bacteria
# OTU_87         ab079634.1 rhodopseudomonas palustris va2_2         Bacteria
# OTU_88                    barnesiella viscericola dsm 18177        Bacteria
# OTU_89                             rhodoblastus acidophilus        Bacteria
# OTU_90                           uncultured acetobacter sp.        Bacteria
# OTU_91                           pleomorphomonas sp. r5_392        Bacteria
# OTU_92                           uncultured bacteroides sp.        Bacteria
# OTU_93     eu765316.1 pervasive effects antibiotic on hum...       Bacteria
# OTU_94                           uncultured bacteroides sp.        Bacteria
# OTU_95                         uncultured prolixibacter sp.        Bacteria
# OTU_96     eu466855.1 african elephant feces clone afel2_...       Bacteria
# OTU_97                                         No hits found     Unassigned
# OTU_98             gu339183.1 pontibacter sp. str. hmd3125         Bacteria
# OTU_99                           uncultured bacteroides sp.        Bacteria
# OTU_100                             atopostipes sp. 17.2 aw        Bacteria
# OTU_101                             uncultured opitutus sp.        Bacteria
# OTU_102    am947938.1 rhodopseudomonas pangongensis str. ...       Bacteria
# OTU_103                          uncultured bacteroides sp.        Bacteria
# OTU_104                            rhodoblastus acidophilus        Bacteria
# OTU_105                             uncultured opitutus sp.        Bacteria
# OTU_106                          uncultured spirochaeta sp.        Bacteria
# OTU_107    eu597423.1 rhodopseudomonas palustris str. rld...       Bacteria
# OTU_108                             uncultured opitutus sp.        Bacteria
# OTU_109                        paludibacter propionicigenes        Bacteria
# OTU_110                            rhodoblastus acidophilus        Bacteria
# OTU_111                          uncultured bacteroides sp.        Bacteria
# OTU_112                                        No hits found     Unassigned
# OTU_113                          rhodopseudomonas palustris        Bacteria
# OTU_114    cu924338.1 towards definition core microorgani...       Bacteria
# OTU_115                             uncultured opitutus sp.        Bacteria
# OTU_116                          uncultured acetobacter sp.        Bacteria
# OTU_117     am490633.1 ochrobactrum intermedium str. tk 14         Bacteria
# OTU_118                             uncultured opitutus sp.        Bacteria
# OTU_119    af025373.1 citrobacter werkmanii str. cdc 0876...       Bacteria
# OTU_120      ab078817.1 propionicimonas paludicola str. k2         Bacteria
# OTU_121                         uncultured salinibacter sp.        Bacteria
# OTU_122                             uncultured opitutus sp.        Bacteria
# OTU_123    am947938.1 rhodopseudomonas pangongensis str. ...       Bacteria
# OTU_124                                        No hits found     Unassigned
# OTU_125                       uncultured steroidobacter sp.        Bacteria
# OTU_126                        uncultured prolixibacter sp.        Bacteria
# OTU_127                          pleomorphomonas sp. r5_392        Bacteria
# OTU_128                           uncultured chlorobium sp.        Bacteria
# OTU_129    ay281086.1 streptococcus sanguinis str. atcc 4...       Bacteria
# OTU_130                         uncultured rhodothermus sp.        Bacteria
# OTU_131    nc_007925.1 rhodopseudomonas palustris str. bi...       Bacteria
# OTU_132                         methyloligella halotolerans        Bacteria
# OTU_133                             uncultured opitutus sp.        Bacteria
# OTU_134             am084007.1 acidovorax sp. str. r_24613         Bacteria
# OTU_135                    eubacterium sp. oral clone ji012        Bacteria
# OTU_136                            rhodoblastus acidophilus        Bacteria
# OTU_137                          uncultured bacteroides sp.        Bacteria
# OTU_138                          uncultured bacteroides sp.        Bacteria
# OTU_139                         uncultured enterobacter sp.        Bacteria
# OTU_140    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_141                      uncultured pleomorphomonas sp.        Bacteria
# OTU_142                           bradyrhizobium sp. wbos16        Bacteria
# OTU_143                         uncultured gemmatimonas sp.        Bacteria
# OTU_144                          uncultured spirochaeta sp.        Bacteria
# OTU_145                          uncultured acetobacter sp.        Bacteria
# OTU_146                      uncultured ancalomicrobium sp.        Bacteria
# OTU_147                         aj229246.1 opitutus terrae         Bacteria
# OTU_148                      pseudochrobactrum kiredjianiae        Bacteria
# OTU_149                          uncultured bacteroides sp.        Bacteria
# OTU_150                      uncultured ancalomicrobium sp.        Bacteria
# OTU_151                     prevotella sp. oral clone gi030        Bacteria
# OTU_152                                        No hits found     Unassigned
# OTU_153                        uncultured prolixibacter sp.        Bacteria
# OTU_154                                        No hits found     Unassigned
# OTU_155    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_156                          uncultured rhodocyclus sp.        Bacteria
# OTU_157                      uncultured ancalomicrobium sp.        Bacteria
# OTU_158                      uncultured ancalomicrobium sp.        Bacteria
# OTU_159                        uncultured porphyromonas sp.        Bacteria
# OTU_160    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_161    aj229247.1 anoxic bulk soil flooded rice micro...       Bacteria
# OTU_162                       uncultured bradyrhizobium sp.        Bacteria
# OTU_163                    eubacterium sp. oral clone ji012        Bacteria
# OTU_164                                    afipia genosp. 6        Bacteria
# OTU_165                          uncultured acetobacter sp.        Bacteria
# OTU_166                            uncultured spirosoma sp.        Bacteria
# OTU_167                                citrobacter sp. f3_3        Bacteria
# OTU_168                          uncultured fibrobacter sp.        Bacteria
# OTU_169                     uncultured sphingobacterium sp.        Bacteria
# OTU_170                          uncultured bacteroides sp.        Bacteria
# OTU_171                         oligotropha carboxidovorans        Bacteria
# OTU_172                         uncultured gemmatimonas sp.        Bacteria
# OTU_173                          uncultured pseudomonas sp.        Bacteria
# OTU_174                          uncultured spirochaeta sp.        Bacteria
# OTU_175                  ay985396.1 human stool clone c334         Bacteria
# OTU_176                          uncultured acetobacter sp.        Bacteria
# OTU_177                             uncultured opitutus sp.        Bacteria
# OTU_178                                  neisseria perflava        Bacteria
# OTU_179                          uncultured nitrobacter sp.        Bacteria
# OTU_180                        uncultured aquabacterium sp.        Bacteria
# OTU_181                          uncultured spirochaeta sp.        Bacteria
# OTU_182                          uncultured spirochaeta sp.        Bacteria
# OTU_183                            rhodoblastus acidophilus        Bacteria
# OTU_184     ab089103.1 termite gut homogenate clone rs_k54         Bacteria
# OTU_185                             uncultured opitutus sp.        Bacteria
# OTU_186                          pleomorphomonas sp. r5_392        Bacteria
# OTU_187    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_188                        uncultured prolixibacter sp.        Bacteria
# OTU_189                        rhodopseudomonas sp. tut3631        Bacteria
# OTU_190    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_191    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_192                        paludibacter propionicigenes        Bacteria
# OTU_193    gq031935.1 topographical and temporal human sk...       Bacteria
# OTU_194    fj719070.1 protozoan grazers alter metabolical...       Bacteria
# OTU_195    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_196        eu399793.1 ochrobactrum anthropi str. pv2z2         Bacteria
# OTU_197    cu924338.1 towards definition core microorgani...       Bacteria
# OTU_198                     uncultured rhodopseudomonas sp.        Bacteria
# OTU_199                        uncultured paenibacillus sp.        Bacteria
# OTU_200    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_201                          uncultured pontibacter sp.        Bacteria
# OTU_202                             uncultured opitutus sp.        Bacteria
# OTU_203    gq027346.1 topographical and temporal human sk...       Bacteria
# OTU_204                          uncultured bacteroides sp.        Bacteria
# OTU_205                          uncultured rhodovibrio sp.        Bacteria
# OTU_206                          uncultured rhodoplanes sp.        Bacteria
# OTU_207                             uncultured opitutus sp.        Bacteria
# OTU_208                            phaeospirillum sp. ja559        Bacteria
# OTU_209                     uncultured thioalkalivibrio sp.        Bacteria
# OTU_210    gq008505.1 topographical and temporal human sk...       Bacteria
# OTU_211                                pontibacter sp. swu8        Bacteria
# OTU_212    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_213                            rhodoblastus acidophilus        Bacteria
# OTU_214    dq837620.1 structures honeybee intestines and ...       Bacteria
# OTU_215                    eubacterium sp. oral clone ji012        Bacteria
# OTU_216                          uncultured pontibacter sp.        Bacteria
# OTU_217                            phaeospirillum sp. ja559        Bacteria
# OTU_218    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_219                          uncultured bacteroides sp.        Bacteria
# OTU_220    af025373.1 citrobacter werkmanii str. cdc 0876...       Bacteria
# OTU_221                                      vitis vinifera   Viridiplantae
# OTU_222    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_223                             uncultured opitutus sp.        Bacteria
# OTU_224                          uncultured pontibacter sp.        Bacteria
# OTU_225                             uncultured opitutus sp.        Bacteria
# OTU_226    gq073996.1 topographical and temporal human sk...       Bacteria
# OTU_227    af025373.1 citrobacter werkmanii str. cdc 0876...       Bacteria
# OTU_228    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_229                          uncultured acetobacter sp.        Bacteria
# OTU_230                             uncultured opitutus sp.        Bacteria
# OTU_231    gq032279.1 topographical and temporal human sk...       Bacteria
# OTU_232                          uncultured rhodovibrio sp.        Bacteria
# OTU_233                         uncultured gemmatimonas sp.        Bacteria
# OTU_234                          uncultured bacteroides sp.        Bacteria
# OTU_235                          flavobacterium sp. r_38296        Bacteria
# OTU_236                          uncultured bacteroides sp.        Bacteria
# OTU_237    ay297803.1 waterlogged archaeological wood clo...       Bacteria
# OTU_238                             uncultured opitutus sp.        Bacteria
# OTU_239    cu924338.1 towards definition core microorgani...       Bacteria
# OTU_240                             uncultured opitutus sp.        Bacteria
# OTU_241                          uncultured bacteroides sp.        Bacteria
# OTU_242                             uncultured opitutus sp.        Bacteria
# OTU_243                             uncultured opitutus sp.        Bacteria
# OTU_244                           uncultured prevotella sp.        Bacteria
# OTU_245                            rhodoblastus acidophilus        Bacteria
# OTU_246    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_247    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_248                          uncultured bacteroides sp.        Bacteria
# OTU_249    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_250    l35502.1 nitrobacter hamburgensis x14 str. nb14         Bacteria
# OTU_251                            uncultured cytophaga sp.        Bacteria
# OTU_252                          uncultured bacteroides sp.        Bacteria
# OTU_253                          rhodopseudomonas palustris        Bacteria
# OTU_254                        uncultured chelatococcus sp.        Bacteria
# OTU_255                             uncultured opitutus sp.        Bacteria
# OTU_256                       uncultured hydrogenophaga sp.        Bacteria
# OTU_257    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_258    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_259    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_260    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_261    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_262    bradyrhizobium sp. enrichment culture clone mw...       Bacteria
# OTU_263                             uncultured opitutus sp.        Bacteria
# OTU_264                          propionicimonas paludicola        Bacteria
# OTU_265                      uncultured ancalomicrobium sp.        Bacteria
# OTU_266                             uncultured opitutus sp.        Bacteria
# OTU_267                                 rhizobium sp. crb31        Bacteria
# OTU_268                          uncultured bacteroides sp.        Bacteria
# OTU_269    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_270                          pleomorphomonas sp. r5_392        Bacteria
# OTU_271                                pontibacter sp. swu8        Bacteria
# OTU_272        dq808485.1 human fecal clone rl239_aaj09b07         Bacteria
# OTU_273                          pleomorphomonas sp. r5_392        Bacteria
# OTU_274                                pontibacter sp. swu8        Bacteria
# OTU_275                    eubacterium sp. oral clone ji012        Bacteria
# OTU_276    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_277    bradyrhizobium sp. enrichment culture clone mw...       Bacteria
# OTU_278                          uncultured bacteroides sp.        Bacteria
# OTU_279                            rhodoblastus acidophilus        Bacteria
# OTU_280                             uncultured opitutus sp.        Bacteria
# OTU_281                      uncultured parabacteroides sp.        Bacteria
# OTU_282                             uncultured opitutus sp.        Bacteria
# OTU_283    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_284                          uncultured escherichia sp.        Bacteria
# OTU_285                ay654810.1 oculina mucus isolate 76         Bacteria
# OTU_286                               methylopila sp. yht_1        Bacteria
# OTU_287                             uncultured opitutus sp.        Bacteria
# OTU_288                             uncultured opitutus sp.        Bacteria
# OTU_289                          uncultured rhodovibrio sp.        Bacteria
# OTU_290      ay323228.1 oribacterium sinus str. aip 354.02         Bacteria
# OTU_291    aj563935.1 methylococcus capsulatus str. texas...       Bacteria
# OTU_292                             uncultured opitutus sp.        Bacteria
# OTU_293                            phaeospirillum sp. ja559        Bacteria
# OTU_294                          uncultured bacteroides sp.        Bacteria
# OTU_295    cu924338.1 towards definition core microorgani...       Bacteria
# OTU_296                                pseudomonas sp. vt1b        Bacteria
# OTU_297    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_298        ab079634.1 rhodopseudomonas palustris va2_2         Bacteria
# OTU_299    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_300                          uncultured bacteroides sp.        Bacteria
# OTU_301                                flexithrix dorotheae        Bacteria
# OTU_302    eu024179.1 burkholderia ubonensis str. cip 107...       Bacteria
# OTU_303    gq080306.1 topographical and temporal human sk...       Bacteria
# OTU_304                          uncultured bacteroides sp.        Bacteria
# OTU_305    ef515194.1 electricigen enrichment mfc upf mic...       Bacteria
# OTU_306    gq009695.1 topographical and temporal human sk...       Bacteria
# OTU_307                              brevundimonas sp. c2e1        Bacteria
# OTU_308                          uncultured acetobacter sp.        Bacteria
# OTU_309                            uncultured aeromonas sp.        Bacteria
# OTU_310                               tumebacillus sp. lx77        Bacteria
# OTU_311                          uncultured spirochaeta sp.        Bacteria
# OTU_312                            phaeospirillum sp. ja559        Bacteria
# OTU_313                          uncultured bacteroides sp.        Bacteria
# OTU_314                             uncultured opitutus sp.        Bacteria
# OTU_315    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_316                          uncultured acetobacter sp.        Bacteria
# OTU_317                          uncultured bacteroides sp.        Bacteria
# OTU_318                          uncultured acetobacter sp.        Bacteria
# OTU_319                          uncultured citrobacter sp.        Bacteria
# OTU_320                             uncultured opitutus sp.        Bacteria
# OTU_321                                escherichia vulneris        Bacteria
# OTU_322                         oligotropha carboxidovorans        Bacteria
# OTU_323                            rhodoblastus acidophilus        Bacteria
# OTU_324                             uncultured opitutus sp.        Bacteria
# OTU_325         aj429239.1 sphingomonas faeni str. ma_olki         Bacteria
# OTU_326    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_327                       uncultured bradyrhizobium sp.        Bacteria
# OTU_328          nc_009485.1 bradyrhizobium sp. str. btai1         Bacteria
# OTU_329                      uncultured ancalomicrobium sp.        Bacteria
# OTU_330                         uncultured enterobacter sp.        Bacteria
# OTU_331    cu925720.1 towards definition core microorgani...       Bacteria
# OTU_332                          uncultured bacteroides sp.        Bacteria
# OTU_333    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_334                          uncultured acetobacter sp.        Bacteria
# OTU_335                            rhodoblastus acidophilus        Bacteria
# OTU_336    aj438048.1 corynebacterium tuberculostearicum ...       Bacteria
# OTU_337                             uncultured opitutus sp.        Bacteria
# OTU_338                                pseudomonas sp. vt1b        Bacteria
# OTU_339                     uncultured rhodopseudomonas sp.        Bacteria
# OTU_340                             clostridium sp. tg60_81        Bacteria
# OTU_341                           bradyrhizobium sp. 1.5_09        Bacteria
# OTU_342                             uncultured opitutus sp.        Bacteria
# OTU_343    gq032543.1 topographical and temporal human sk...       Bacteria
# OTU_344    fj471664.1 fusobacterium nucleatum str. chdc f...       Bacteria
# OTU_345                   barnesiella viscericola dsm 18177        Bacteria
# OTU_346                             uncultured opitutus sp.        Bacteria
# OTU_347                          uncultured rhodoplanes sp.        Bacteria
# OTU_348                        enterobacter sp. gntew_13_11        Bacteria
# OTU_349                            rhodoblastus acidophilus        Bacteria
# OTU_350                       uncultured steroidobacter sp.        Bacteria
# OTU_351                    eubacterium sp. oral clone ji012        Bacteria
# OTU_352                             uncultured opitutus sp.        Bacteria
# OTU_353                          uncultured spirochaeta sp.        Bacteria
# OTU_354                             uncultured opitutus sp.        Bacteria
# OTU_355                         uncultured enterobacter sp.        Bacteria
# OTU_356                          uncultured bacteroides sp.        Bacteria
# OTU_357    cp000463.1 rhodopseudomonas palustris str. bis...       Bacteria
# OTU_358                     prevotella sp. oral clone do039        Bacteria
# OTU_359    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_360                      uncultured pleomorphomonas sp.        Bacteria
# OTU_361    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_362    cu924338.1 towards definition core microorgani...       Bacteria
# OTU_363                     uncultured rhodopseudomonas sp.        Bacteria
# OTU_364                          uncultured acetobacter sp.        Bacteria
# OTU_365              ab079679.1 rhodopseudomonas sp. hmd89         Bacteria
# OTU_366                             uncultured opitutus sp.        Bacteria
# OTU_367    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_368                          uncultured citrobacter sp.        Bacteria
# OTU_369                   barnesiella viscericola dsm 18177        Bacteria
# OTU_370                            rhodoblastus acidophilus        Bacteria
# OTU_371                          uncultured pontibacter sp.        Bacteria
# OTU_372                          uncultured bacteroides sp.        Bacteria
# OTU_373                             uncultured opitutus sp.        Bacteria
# OTU_374                          uncultured bacteroides sp.        Bacteria
# OTU_375                           uncultured chlorobium sp.        Bacteria
# OTU_376                          uncultured rhodovibrio sp.        Bacteria
# OTU_377                          uncultured citrobacter sp.        Bacteria
# OTU_378                            rhodoblastus acidophilus        Bacteria
# OTU_379                          uncultured bacteroides sp.        Bacteria
# OTU_380                      uncultured pleomorphomonas sp.        Bacteria
# OTU_381                          uncultured bacteroides sp.        Bacteria
# OTU_382                      uncultured pleomorphomonas sp.        Bacteria
# OTU_383    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_384                        phyllobacterium sp. ccge2278        Bacteria
# OTU_385                             uncultured opitutus sp.        Bacteria
# OTU_386                             uncultured opitutus sp.        Bacteria
# OTU_387    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_388                          uncultured rhodocyclus sp.        Bacteria
# OTU_389                          uncultured acetobacter sp.        Bacteria
# OTU_390                            rhodoblastus acidophilus        Bacteria
# OTU_391            fj903178.1 pontibacter sp. str. hmc6020         Bacteria
# OTU_392                            rhodoblastus acidophilus        Bacteria
# OTU_393    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_394                          uncultured spirochaeta sp.        Bacteria
# OTU_395                          uncultured acetobacter sp.        Bacteria
# OTU_396    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_397    gq503798.1 uranium mine tailing pond inlet wat...       Bacteria
# OTU_398    ay373320.1 bacillus thermoamylovorans str. r_7...       Bacteria
# OTU_399    gq070490.1 topographical and temporal human sk...       Bacteria
# OTU_400                            rhodoblastus acidophilus        Bacteria
# OTU_401                             uncultured opitutus sp.        Bacteria
# OTU_402                             uncultured opitutus sp.        Bacteria
# OTU_403    am947938.1 rhodopseudomonas pangongensis str. ...       Bacteria
# OTU_404    gq015335.1 topographical and temporal human sk...       Bacteria
# OTU_405                             uncultured opitutus sp.        Bacteria
# OTU_406                          uncultured bacteroides sp.        Bacteria
# OTU_407    fj749471.1 lactobacillus helveticus str. imau5...       Bacteria
# OTU_408                          uncultured bacteroides sp.        Bacteria
# OTU_409                             uncultured opitutus sp.        Bacteria
# OTU_410                          uncultured spirochaeta sp.        Bacteria
# OTU_411                      uncultured pleomorphomonas sp.        Bacteria
# OTU_412    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_413                                     delftia sp. j01        Bacteria
# OTU_414                          rhodopseudomonas palustris        Bacteria
# OTU_415                            rhodoblastus acidophilus        Bacteria
# OTU_416                           uncultured chlorobium sp.        Bacteria
# OTU_417                            rhodoblastus acidophilus        Bacteria
# OTU_418                         uncultured beijerinckia sp.        Bacteria
# OTU_419                     uncultured rhodopseudomonas sp.        Bacteria
# OTU_420                                prevotella sp. icm55        Bacteria
# OTU_421    cu924338.1 towards definition core microorgani...       Bacteria
# OTU_422                          uncultured spirochaeta sp.        Bacteria
# OTU_423        dq808485.1 human fecal clone rl239_aaj09b07         Bacteria
# OTU_424    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_425                          rhodopseudomonas palustris        Bacteria
# OTU_426         ab159681.1 pleomorphomonas oryzae str. f_4         Bacteria
# OTU_427                           uncultured chlorobium sp.        Bacteria
# OTU_428                          uncultured bacteroides sp.        Bacteria
# OTU_429                            rhodoblastus acidophilus        Bacteria
# OTU_430                            rhodoblastus acidophilus        Bacteria
# OTU_431                             uncultured opitutus sp.        Bacteria
# OTU_432    cu924338.1 towards definition core microorgani...       Bacteria
# OTU_433                         uncultured globicatella sp.        Bacteria
# OTU_434                            phaeospirillum sp. ja559        Bacteria
# OTU_435                             uncultured opitutus sp.        Bacteria
# OTU_436    cu924338.1 towards definition core microorgani...       Bacteria
# OTU_437                          rhodopseudomonas palustris        Bacteria
# OTU_438    fm873047.1 occupant source house floor dust cl...       Bacteria
# OTU_439                          uncultured pontibacter sp.        Bacteria
# OTU_440                             uncultured opitutus sp.        Bacteria
# OTU_441                             uncultured opitutus sp.        Bacteria
# OTU_442    am947938.1 rhodopseudomonas pangongensis str. ...       Bacteria
# OTU_443                          uncultured spirochaeta sp.        Bacteria
# OTU_444    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_445                             phaeospirillum sp. ak32        Bacteria
# OTU_446                          uncultured bacteroides sp.        Bacteria
# OTU_447                          uncultured acetobacter sp.        Bacteria
# OTU_448    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_449    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_450        cp001280.1 methylocella silvestris str. bl2         Bacteria
# OTU_451                                    afipia genosp. 6        Bacteria
# OTU_452                             uncultured opitutus sp.        Bacteria
# OTU_453                             uncultured opitutus sp.        Bacteria
# OTU_454       nc_010376.1 finegoldia magna str. atcc 29328         Bacteria
# OTU_455    af025373.1 citrobacter werkmanii str. cdc 0876...       Bacteria
# OTU_456    cu924338.1 towards definition core microorgani...       Bacteria
# OTU_457                          uncultured pontibacter sp.        Bacteria
# OTU_458                   barnesiella viscericola dsm 18177        Bacteria
# OTU_459                          uncultured citrobacter sp.        Bacteria
# OTU_460                             uncultured opitutus sp.        Bacteria
# OTU_461                        paludibacter propionicigenes        Bacteria
# OTU_462                           uncultured chlorobium sp.        Bacteria
# OTU_463    cu924338.1 towards definition core microorgani...       Bacteria
# OTU_464    cu924338.1 towards definition core microorgani...       Bacteria
# OTU_465                          uncultured bacteroides sp.        Bacteria
# OTU_466                        paludibacter propionicigenes        Bacteria
# OTU_467    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_468                          uncultured acetobacter sp.        Bacteria
# OTU_469             am992194.1 micrococcus luteus ts iw 23         Bacteria
# OTU_470                             uncultured opitutus sp.        Bacteria
# OTU_471              ab079679.1 rhodopseudomonas sp. hmd89         Bacteria
# OTU_472    af025373.1 citrobacter werkmanii str. cdc 0876...       Bacteria
# OTU_473           aj620346.1 rubrivivax indolicus str. ou5         Bacteria
# OTU_474                          uncultured bacteroides sp.        Bacteria
# OTU_475       y15408.1 granulicatella elegans str. 2640_91         Bacteria
# OTU_476                      uncultured ancalomicrobium sp.        Bacteria
# OTU_477                             uncultured opitutus sp.        Bacteria
# OTU_478    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_479                    eubacterium sp. oral clone ji012        Bacteria
# OTU_480                        paludibacter propionicigenes        Bacteria
# OTU_481    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_482                            uncultured roseburia sp.        Bacteria
# OTU_483                          uncultured bacteroides sp.        Bacteria
# OTU_484                             uncultured opitutus sp.        Bacteria
# OTU_485                            rhodoblastus acidophilus        Bacteria
# OTU_486                          uncultured bacteroides sp.        Bacteria
# OTU_487                            rhodoblastus acidophilus        Bacteria
# OTU_488                   barnesiella viscericola dsm 18177        Bacteria
# OTU_489                            rhodoblastus acidophilus        Bacteria
# OTU_490                              methylocystis sp. m167        Bacteria
# OTU_491         opitutus sp. enrichment culture clone lt_b7        Bacteria
# OTU_492                          uncultured fibrobacter sp.        Bacteria
# OTU_493                      uncultured ancalomicrobium sp.        Bacteria
# OTU_494                      uncultured ancalomicrobium sp.        Bacteria
# OTU_495                             uncultured opitutus sp.        Bacteria
# OTU_496                         uncultured ruminococcus sp.        Bacteria
# OTU_497    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_498    y17601.1 propionivibrio dicarboxylicus str. ds...       Bacteria
# OTU_499                                uncultured bosea sp.        Bacteria
# OTU_500                          uncultured pontibacter sp.        Bacteria
# OTU_501                                 pantoea agglomerans        Bacteria
# OTU_502    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_503                            bradyrhizobium sp. s2hs2        Bacteria
# OTU_504                      uncultured pleomorphomonas sp.        Bacteria
# OTU_505                          uncultured rhodocyclus sp.        Bacteria
# OTU_506                          uncultured pontibacter sp.        Bacteria
# OTU_507                           uncultured chlorobium sp.        Bacteria
# OTU_508                          uncultured bacteroides sp.        Bacteria
# OTU_509                             uncultured opitutus sp.        Bacteria
# OTU_510                             uncultured opitutus sp.        Bacteria
# OTU_511    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_512                             uncultured opitutus sp.        Bacteria
# OTU_513                        uncultured paenibacillus sp.        Bacteria
# OTU_514    dq342320.1 rhodobacter capsulatus str. atcc 11...       Bacteria
# OTU_515                            rhodoblastus acidophilus        Bacteria
# OTU_516    cu924338.1 towards definition core microorgani...       Bacteria
# OTU_517    eu467239.1 black_handed spider monkey feces cl...       Bacteria
# OTU_518              ab079679.1 rhodopseudomonas sp. hmd89         Bacteria
# OTU_519                             uncultured opitutus sp.        Bacteria
# OTU_520                            rhodoblastus acidophilus        Bacteria
# OTU_521                    eubacterium sp. oral clone ji012        Bacteria
# OTU_522                          uncultured acetobacter sp.        Bacteria
# OTU_523                          pleomorphomonas sp. r5_392        Bacteria
# OTU_524    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_525                               methylocystis heyerii        Bacteria
# OTU_526                   gq129971.1 genetic inventory &apos       Bacteria
# OTU_527    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_528    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_529    nz_acik02000004.1 veillonella dispar str. atcc...       Bacteria
# OTU_530    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_531         aj249327.1 actinomyces sp. str. ccug 41710         Bacteria
# OTU_532                             uncultured opitutus sp.        Bacteria
# OTU_533        cp001280.1 methylocella silvestris str. bl2         Bacteria
# OTU_534                            bradyrhizobium sp. s2hs2        Bacteria
# OTU_535                          uncultured clostridium sp.        Bacteria
# OTU_536                             brevundimonas sp. c1403        Bacteria
# OTU_537    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_538    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_539    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_540                             uncultured opitutus sp.        Bacteria
# OTU_541    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_542              ab079679.1 rhodopseudomonas sp. hmd89         Bacteria
# OTU_543                         uncultured beijerinckia sp.        Bacteria
# OTU_544    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_545    am947938.1 rhodopseudomonas pangongensis str. ...       Bacteria
# OTU_546                   barnesiella viscericola dsm 18177        Bacteria
# OTU_547                          uncultured acetobacter sp.        Bacteria
# OTU_548    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_549                          uncultured pontibacter sp.        Bacteria
# OTU_550                             uncultured opitutus sp.        Bacteria
# OTU_551    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_552                          uncultured spirochaeta sp.        Bacteria
# OTU_553    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_554                          uncultured pontibacter sp.        Bacteria
# OTU_555    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_556                          uncultured pontibacter sp.        Bacteria
# OTU_557                          uncultured bacteroides sp.        Bacteria
# OTU_558                          uncultured bacteroides sp.        Bacteria
# OTU_559    aj229247.1 anoxic bulk soil flooded rice micro...       Bacteria
# OTU_560                   barnesiella viscericola dsm 18177        Bacteria
# OTU_561                          uncultured bacteroides sp.        Bacteria
# OTU_562    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_563    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_564    gq071983.1 topographical and temporal human sk...       Bacteria
# OTU_565                             uncultured opitutus sp.        Bacteria
# OTU_566                            rhodoblastus acidophilus        Bacteria
# OTU_567    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_568                          uncultured fibrobacter sp.        Bacteria
# OTU_569                          uncultured caulobacter sp.        Bacteria
# OTU_570    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_571                                     stappia sp. e19        Bacteria
# OTU_572                             uncultured opitutus sp.        Bacteria
# OTU_573    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# OTU_574                             uncultured opitutus sp.        Bacteria
# OTU_575    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_576                          uncultured clostridium sp.        Bacteria
# OTU_577                              uncultured dietzia sp.        Bacteria
# OTU_578                          uncultured acetobacter sp.        Bacteria
# OTU_579                          uncultured spirochaeta sp.        Bacteria
# OTU_580                          uncultured bacteroides sp.        Bacteria
# OTU_581                         uncultured enterobacter sp.        Bacteria
# OTU_582         opitutus sp. enrichment culture clone lt_b7        Bacteria
# OTU_583    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_584                          uncultured bacteroides sp.        Bacteria
# OTU_585        ab079634.1 rhodopseudomonas palustris va2_2         Bacteria
# OTU_586                                pontibacter sp. swu8        Bacteria
# OTU_587                             uncultured opitutus sp.        Bacteria
# OTU_588                         uncultured enterobacter sp.        Bacteria
# OTU_589    ab087719.1 rhodopseudomonas rhenobacensis str....       Bacteria
# OTU_590                          uncultured bacteroides sp.        Bacteria
# OTU_591                             uncultured opitutus sp.        Bacteria
# OTU_592    cu924338.1 towards definition core microorgani...       Bacteria
# OTU_593                               tumebacillus sp. lx77        Bacteria
# OTU_594                        uncultured brevundimonas sp.        Bacteria
# OTU_595                       uncultured bradyrhizobium sp.        Bacteria
# OTU_596        clostridium sp. enrichment culture clone ht3        Bacteria
# OTU_597                            rhodoblastus acidophilus        Bacteria
# OTU_598    methylobacillus sp. enrichment culture clone n...       Bacteria
# OTU_599                          uncultured spirochaeta sp.        Bacteria
# OTU_600                            rhodoblastus acidophilus        Bacteria
# OTU_601    eu528231.1 seasonal dynamics mudflat mouth maj...       Bacteria
# OTU_602                     uncultured rhodopseudomonas sp.        Bacteria
# OTU_603    aj582755.1 desulfovibrio ferrireducens str. cy1         Bacteria
# OTU_604    cp000463.1 rhodopseudomonas palustris str. bis...       Bacteria
# OTU_605    ay297802.1 waterlogged archaeological wood clo...       Bacteria
# ...
# OTU_398               Unassigned                    Unassigned
# OTU_399      __corynebacterineae                    Unassigned
# OTU_400               Unassigned                    Unassigned
# OTU_401               Unassigned                    Unassigned
# OTU_402               Unassigned                    Unassigned
# OTU_403               Unassigned                    Unassigned
# OTU_404               Unassigned                    Unassigned
# OTU_405               Unassigned                    Unassigned
# OTU_406               Unassigned                    Unassigned
# OTU_407               Unassigned                    Unassigned
# OTU_408               Unassigned                    Unassigned
# OTU_409               Unassigned                    Unassigned
# OTU_410               Unassigned                    Unassigned
# OTU_411               Unassigned                    Unassigned
# OTU_412               Unassigned                    Unassigned
# OTU_413               Unassigned                    Unassigned
# OTU_414               Unassigned                    Unassigned
# OTU_415               Unassigned                    Unassigned
# OTU_416               Unassigned                    Unassigned
# OTU_417               Unassigned                    Unassigned
# OTU_418               Unassigned                    Unassigned
# OTU_419               Unassigned                    Unassigned
# OTU_420               Unassigned                    Unassigned
# OTU_421               Unassigned                    Unassigned
# OTU_422               Unassigned                    Unassigned
# OTU_423               Unassigned                    Unassigned
# OTU_424               Unassigned                    Unassigned
# OTU_425               Unassigned                    Unassigned
# OTU_426               Unassigned                    Unassigned
# OTU_427               Unassigned                    Unassigned
# OTU_428               Unassigned                    Unassigned
# OTU_429               Unassigned                    Unassigned
# OTU_430               Unassigned                    Unassigned
# OTU_431               Unassigned                    Unassigned
# OTU_432               Unassigned                    Unassigned
# OTU_433               Unassigned                    Unassigned
# OTU_434               Unassigned                    Unassigned
# OTU_435               Unassigned                    Unassigned
# OTU_436               Unassigned                    Unassigned
# OTU_437               Unassigned                    Unassigned
# OTU_438               Unassigned                    Unassigned
# OTU_439               Unassigned                    Unassigned
# OTU_440               Unassigned                    Unassigned
# OTU_441               Unassigned                    Unassigned
# OTU_442               Unassigned                    Unassigned
# OTU_443               Unassigned                    Unassigned
# OTU_444               Unassigned                    Unassigned
# OTU_445               Unassigned                    Unassigned
# OTU_446               Unassigned                    Unassigned
# OTU_447               Unassigned                    Unassigned
# OTU_448               Unassigned                    Unassigned
# OTU_449               Unassigned                    Unassigned
# OTU_450               Unassigned                    Unassigned
# OTU_451               Unassigned                    Unassigned
# OTU_452               Unassigned                    Unassigned
# OTU_453               Unassigned                    Unassigned
# OTU_454               Unassigned                    Unassigned
# OTU_455               Unassigned                    Unassigned
# OTU_456               Unassigned                    Unassigned
# OTU_457               Unassigned                    Unassigned
# OTU_458               Unassigned                    Unassigned
# OTU_459               Unassigned                    Unassigned
# OTU_460               Unassigned                    Unassigned
# OTU_461               Unassigned                    Unassigned
# OTU_462               Unassigned                    Unassigned
# OTU_463               Unassigned                    Unassigned
# OTU_464               Unassigned                    Unassigned
# OTU_465               Unassigned                    Unassigned
# OTU_466               Unassigned                    Unassigned
# OTU_467               Unassigned                    Unassigned
# OTU_468               Unassigned                    Unassigned
# OTU_469         __micrococcineae                    Unassigned
# OTU_470               Unassigned                    Unassigned
# OTU_471               Unassigned                    Unassigned
# OTU_472               Unassigned                    Unassigned
# OTU_473               Unassigned                    Unassigned
# OTU_474               Unassigned                    Unassigned
# OTU_475               Unassigned                    Unassigned
# OTU_476               Unassigned                    Unassigned
# OTU_477               Unassigned                    Unassigned
# OTU_478               Unassigned                    Unassigned
# OTU_479               Unassigned                    Unassigned
# OTU_480               Unassigned                    Unassigned
# OTU_481               Unassigned                    Unassigned
# OTU_482               Unassigned                    Unassigned
# OTU_483               Unassigned                    Unassigned
# OTU_484               Unassigned                    Unassigned
# OTU_485               Unassigned                    Unassigned
# OTU_486               Unassigned                    Unassigned
# OTU_487               Unassigned                    Unassigned
# OTU_488               Unassigned                    Unassigned
# OTU_489               Unassigned                    Unassigned
# OTU_490               Unassigned                    Unassigned
# OTU_491               Unassigned                    Unassigned
# OTU_492               Unassigned                    Unassigned
# OTU_493               Unassigned                    Unassigned
# OTU_494               Unassigned                    Unassigned
# OTU_495               Unassigned                    Unassigned
# OTU_496               Unassigned                    Unassigned
# OTU_497               Unassigned                    Unassigned
# OTU_498               Unassigned                    Unassigned
# OTU_499               Unassigned                    Unassigned
# OTU_500               Unassigned                    Unassigned
# OTU_501               Unassigned                    Unassigned
# OTU_502               Unassigned                    Unassigned
# OTU_503               Unassigned                    Unassigned
# OTU_504               Unassigned                    Unassigned
# OTU_505               Unassigned                    Unassigned
# OTU_506               Unassigned                    Unassigned
# OTU_507               Unassigned                    Unassigned
# OTU_508               Unassigned                    Unassigned
# OTU_509               Unassigned                    Unassigned
# OTU_510               Unassigned                    Unassigned
# OTU_511               Unassigned                    Unassigned
# OTU_512               Unassigned                    Unassigned
# OTU_513               Unassigned                    Unassigned
# OTU_514               Unassigned                    Unassigned
# OTU_515               Unassigned                    Unassigned
# OTU_516               Unassigned                    Unassigned
# OTU_517               Unassigned                    Unassigned
# OTU_518               Unassigned                    Unassigned
# OTU_519               Unassigned                    Unassigned
# OTU_520               Unassigned                    Unassigned
# OTU_521               Unassigned                    Unassigned
# OTU_522               Unassigned                    Unassigned
# OTU_523               Unassigned                    Unassigned
# OTU_524               Unassigned                    Unassigned
# OTU_525               Unassigned                    Unassigned
# OTU_526               Unassigned                    Unassigned
# OTU_527               Unassigned                    Unassigned
# OTU_528               Unassigned                    Unassigned
# OTU_529               Unassigned                    Unassigned
# OTU_530               Unassigned                    Unassigned
# OTU_531         __actinomycineae                    Unassigned
# OTU_532               Unassigned                    Unassigned
# OTU_533               Unassigned                    Unassigned
# OTU_534               Unassigned                    Unassigned
# OTU_535               Unassigned                    Unassigned
# OTU_536               Unassigned                    Unassigned
# OTU_537               Unassigned                    Unassigned
# OTU_538               Unassigned                    Unassigned
# OTU_539               Unassigned                    Unassigned
# OTU_540               Unassigned                    Unassigned
# OTU_541               Unassigned                    Unassigned
# OTU_542               Unassigned                    Unassigned
# OTU_543               Unassigned                    Unassigned
# OTU_544               Unassigned                    Unassigned
# OTU_545               Unassigned                    Unassigned
# OTU_546               Unassigned                    Unassigned
# OTU_547               Unassigned                    Unassigned
# OTU_548               Unassigned                    Unassigned
# OTU_549               Unassigned                    Unassigned
# OTU_550               Unassigned                    Unassigned
# OTU_551               Unassigned                    Unassigned
# OTU_552               Unassigned                    Unassigned
# OTU_553               Unassigned                    Unassigned
# OTU_554               Unassigned                    Unassigned
# OTU_555               Unassigned                    Unassigned
# OTU_556               Unassigned                    Unassigned
# OTU_557               Unassigned                    Unassigned
# OTU_558               Unassigned                    Unassigned
# OTU_559               Unassigned                    Unassigned
# OTU_560               Unassigned                    Unassigned
# OTU_561               Unassigned                    Unassigned
# OTU_562               Unassigned                    Unassigned
# OTU_563               Unassigned                    Unassigned
# OTU_564               Unassigned                    Unassigned
# OTU_565               Unassigned                    Unassigned
# OTU_566               Unassigned                    Unassigned
# OTU_567               Unassigned                    Unassigned
# OTU_568               Unassigned                    Unassigned
# OTU_569               Unassigned                    Unassigned
# OTU_570               Unassigned                    Unassigned
# OTU_571               Unassigned                    Unassigned
# OTU_572               Unassigned                    Unassigned
# OTU_573               Unassigned                    Unassigned
# OTU_574               Unassigned                    Unassigned
# OTU_575               Unassigned                    Unassigned
# OTU_576               Unassigned                    Unassigned
# OTU_577      __corynebacterineae                    Unassigned
# OTU_578               Unassigned                    Unassigned
# OTU_579               Unassigned                    Unassigned
# OTU_580               Unassigned                    Unassigned
# OTU_581               Unassigned                    Unassigned
# OTU_582               Unassigned                    Unassigned
# OTU_583               Unassigned                    Unassigned
# OTU_584               Unassigned                    Unassigned
# OTU_585               Unassigned                    Unassigned
# OTU_586               Unassigned                    Unassigned
# OTU_587               Unassigned                    Unassigned
# OTU_588               Unassigned                    Unassigned
# OTU_589               Unassigned                    Unassigned
# OTU_590               Unassigned                    Unassigned
# OTU_591               Unassigned                    Unassigned
# OTU_592               Unassigned                    Unassigned
# OTU_593               Unassigned                    Unassigned
# OTU_594               Unassigned                    Unassigned
# OTU_595               Unassigned                    Unassigned
# OTU_596               Unassigned                    Unassigned
# OTU_597               Unassigned                    Unassigned
# OTU_598               Unassigned                    Unassigned
# OTU_599               Unassigned                    Unassigned
# OTU_600               Unassigned                    Unassigned
# OTU_601               Unassigned                    Unassigned
# OTU_602               Unassigned                    Unassigned
# OTU_603               Unassigned  __delta/epsilon subdivisions
# OTU_604               Unassigned                    Unassigned
# OTU_605               Unassigned                    Unassigned
# OTU_606               Unassigned                    Unassigned
# OTU_607               Unassigned                    Unassigned
# OTU_608               Unassigned                    Unassigned
# OTU_609               Unassigned                    Unassigned
# OTU_610               Unassigned                    Unassigned
# OTU_611               Unassigned                    Unassigned
# OTU_612               Unassigned                    Unassigned
# OTU_613               Unassigned                    Unassigned
# OTU_614               Unassigned                    Unassigned
# OTU_615               Unassigned                    Unassigned
# OTU_616               Unassigned                    Unassigned
# OTU_617               Unassigned                    Unassigned
# OTU_618               Unassigned                    Unassigned
# OTU_619               Unassigned                    Unassigned
# OTU_620               Unassigned                    Unassigned
# OTU_621               Unassigned                    Unassigned
# OTU_622               Unassigned                    Unassigned
# OTU_623               Unassigned                    Unassigned
# OTU_624               Unassigned                    Unassigned
# OTU_625               Unassigned                    Unassigned
# OTU_626               Unassigned                    Unassigned
# OTU_627               Unassigned                    Unassigned
# OTU_628               Unassigned                    Unassigned
# OTU_629               Unassigned                    Unassigned
# OTU_630               Unassigned                    Unassigned
# OTU_631               Unassigned                    Unassigned
# OTU_632               Unassigned                    Unassigned
# OTU_633               Unassigned                    Unassigned
# OTU_634               Unassigned                    Unassigned
# OTU_635               Unassigned                    Unassigned
# OTU_636               Unassigned                    Unassigned
# OTU_637               Unassigned                    Unassigned
# OTU_638               Unassigned                    Unassigned
# OTU_639               Unassigned                    Unassigned
# OTU_640               Unassigned                    Unassigned
# OTU_641               Unassigned                    Unassigned
# OTU_642               Unassigned                    Unassigned
# OTU_643               Unassigned                    Unassigned

# %%
# check for unassigned genus
print(feature_metadata[feature_metadata["genus"] == "Unassigned"].shape)
# check for unassigned species
print(feature_metadata[feature_metadata["species"] == "Unassigned"].shape)
# Out:
# (5, 14)
# (5, 14)

# %% [markdown]
# ### Additional Cleaning (Do Not Threshold OTUs)

# %%
# check if there are OTUs that appear in no samples
OTU_counts[OTU_counts.sum(axis=1) == 0]
# Out:
# Empty DataFrame
# Columns: [sC0C, s1C03A, s1C03B, s1C05A, s1C05B, s1C07A, s1C07B, s1C10A, s1C10B, s1C20A, s1C20B, s2C03A, s2C03B, s2C05A, s2C05B, s2C10A, s2C10B, s1M03A, s1M03B, s1M03C, s1M05C, s1M05A, s1M05B, s1M07A, s1M07B, s1M07C, s1M10A, s1M10B, s1M10C, s2M03A, s2M03B, s2M03C, s2M05A, s2M05B, s2M07A, s2M07B, s2M10B, s2M10A, s2M10C, s3M03A, s3M03B, s3M03C, s3M05A, s3M05B, s3M05C, s3M07A, s3M07B, s3M07C, s3M10A, s3M10B, s3M10C, s1G03A, s1G03B, s1G03C, s1G05A, s1G05B, s1G05C, s1G07A, s1G07B, s1G07C, s1G10A, s1G10B, s1G10C, s2G03A, s2G03B, s2G03C, s2G05A, s2G05B, s2G05C, s2G07A, s2G07B, s2G07C, s2G10A, s2G10B, s2G10C, s3G03A, s3G03B, s3G03C, s3G05A, s3G05B, s3G05C, s3G07A, s3G07B, s3G07C, s3G10A, s3G10B]
# Index: []
#
# [0 rows x 86 columns]

# %%
# check if there are Unassigned taxonomy OTUs
not_assigned = feature_metadata[feature_metadata["taxonomy"] == "Unassigned"]
print(not_assigned.Name)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
OTU_counts.loc[list(not_assigned.index), :]
# Out:
# featureID
# OTU_97     No hits found
# OTU_112    No hits found
# OTU_124    No hits found
# OTU_152    No hits found
# OTU_154    No hits found
# Name: Name, dtype: object
#            sC0C  s1C03A  s1C03B  s1C05A  s1C05B  s1C07A  s1C07B  s1C10A  \
# featureID
# OTU_97        0       0       0       0       0       0       0       0
# OTU_112       0       0       0       0       0       0       0       0
# OTU_124       0       0       0       0       0       0       0       0
# OTU_152       0       0       0       0       0       0       0       0
# OTU_154       0       0       0       0       0       0       0       0
#
#            s1C10B  s1C20A  s1C20B  s2C03A  s2C03B  s2C05A  s2C05B  s2C10A  \
# featureID
# OTU_97          0       0       0       0      42       0       0       0
# OTU_112         0       0       0       0       0       0       0       0
# OTU_124         0       0       0       0       0       0       0       0
# OTU_152         0       0       0       0       0       0       0       0
# OTU_154         0       0       0       0       0       0       0       0
#
#            s2C10B  s1M03A  s1M03B  s1M03C  s1M05C  s1M05A  s1M05B  s1M07A  \
# featureID
# OTU_97          0       0       0       0       0       0       0       0
# OTU_112         0       0       0       0       0       0       0       0
# OTU_124         0       0       0       0       0       0       0       0
# OTU_152         0       0       0       0       0       0       0       0
# OTU_154         0       0       0       0       0       0       0       0
#
#            s1M07B  s1M07C  s1M10A  s1M10B  s1M10C  s2M03A  s2M03B  s2M03C  \
# featureID
# OTU_97          0       0       0       0       0       0       0       0
# OTU_112         0       0       0       0       0       0       0       0
# OTU_124         0       0       0       0       0       0       0       0
# OTU_152        15       0       0       0       0       0       0       0
# OTU_154         0       0       0       0       0       0       0       0
#
#            s2M05A  s2M05B  s2M07A  s2M07B  s2M10B  s2M10A  s2M10C  s3M03A  \
# featureID
# OTU_97          0       0       0       0       0       0       0       0
# OTU_112         0       0       0       0       0       0       0       0
# OTU_124         0       0       0       0       0       0       0       0
# OTU_152         0       0       0       0       0       0       0       0
# OTU_154         0       0       0       0       0       0       0       0
#
#            s3M03B  s3M03C  s3M05A  s3M05B  s3M05C  s3M07A  s3M07B  s3M07C  \
# featureID
# OTU_97          0       0       0       0       0       0       0       0
# OTU_112         0       0       0       0       0      35       0       0
# OTU_124         0       0       0       0       0       0       0       0
# OTU_152         0       0       0       0       0       0       0       0
# OTU_154         0       0       0       0       0       0       0       0
#
#            s3M10A  s3M10B  s3M10C  s1G03A  s1G03B  s1G03C  s1G05A  s1G05B  \
# featureID
# OTU_97          0       0       0       1       0       0       0       0
# OTU_112         0       0       0       0       0       0       0       0
# OTU_124         0       0       0      18       0       0       0       0
# OTU_152         0       0       0       0       0       0       0       0
# OTU_154         0       0       0       0       0       0       0       0
#
#            s1G05C  s1G07A  s1G07B  s1G07C  s1G10A  s1G10B  s1G10C  s2G03A  \
# featureID
# OTU_97          0       0       0       0       0       0       0       0
# OTU_112         0       0       0       0       0       0       0       0
# OTU_124         0       0       0       0       0       0       0       0
# OTU_152         0       0       0       0       0       0       0       0
# OTU_154         0       0       0       0       0       9       0       0
#
#            s2G03B  s2G03C  s2G05A  s2G05B  s2G05C  s2G07A  s2G07B  s2G07C  \
# featureID
# OTU_97          0       0       0       0       0       0       0       0
# OTU_112         0      33       0       0       0       0       0       0
# OTU_124         0       0      28       0       0       0       0       0
# OTU_152         0       0       0       0       0       0       0       0
# OTU_154         0       0       0       0       0       0       0       0
#
#            s2G10A  s2G10B  s2G10C  s3G03A  s3G03B  s3G03C  s3G05A  s3G05B  \
# featureID
# OTU_97          0       0       0       0       0       0       0       0
# OTU_112         0       0       0       0       0       0       0       0
# OTU_124         0       0       0       0       0       0       0       0
# OTU_152         0       0       0       0      14       0       0       0
# OTU_154         0       0       0       0       0       0      19       0
#
#            s3G05C  s3G07A  s3G07B  s3G07C  s3G10A  s3G10B
# featureID
# OTU_97          1      48       0       0       0       0
# OTU_112         0       0       0       0       0       0
# OTU_124         0       0       0       0      11       0
# OTU_152         0       0       0       0       0       0
# OTU_154         0       0       0       0       0       0

# %%
# check if any of the unassigned OTUs appear in 20% of samples
(OTU_counts.loc[list(not_assigned.index), :] > 1).sum(axis=1)
# Out:
# featureID
# OTU_97     2
# OTU_112    2
# OTU_124    3
# OTU_152    2
# OTU_154    2
# dtype: int64

# %%
OTU_counts = OTU_counts.drop(not_assigned.index)
print("OTU_counts.shape", OTU_counts.shape)

feature_metadata = feature_metadata.drop(not_assigned.index)
print("feature_metadata.shape", feature_metadata.shape)
# Out:
# OTU_counts.shape (638, 86)
# feature_metadata.shape (638, 14)

# %%
# remove OTUs that are not bacteria
not_bacteria = feature_metadata[feature_metadata["kingdom"] != "Bacteria"]
print(not_bacteria.Name)

OTU_counts = OTU_counts.drop(not_bacteria.index)
print("OTU_counts.shape", OTU_counts.shape)

feature_metadata = feature_metadata.drop(not_bacteria.index)
print("feature_metadata.shape", feature_metadata.shape)
# Out:
# featureID
# OTU_55     uncultured methanosaeta sp.
# OTU_221                 vitis vinifera
# Name: Name, dtype: object
# OTU_counts.shape (636, 86)
# feature_metadata.shape (636, 14)

# %% [markdown]
# ## Get Phylogenetic Info and Alignment Scores
#
# * OTU ID: DNA Sequences
#     * (MR DNA): `081616JHnew515Fcomplete-pr.fasta.otus.fa`
# * OTU ID x OTU ID Pairwise Alignment Scores
#     * (Muscle): `Pairwise_distances_all_OTU_Muscle`
# * OTU ID Phylogenetic Tree
#     * (Muscle): `MUSCLE_alignment_ML_tree_all_OTUs`

# %% [markdown]
# ### Rename OTU ID: DNA Sequences mapping (for Jean, to visually analyze phylogenetic tree)

# %%
from skbio.sequence import DNA

sequence_file = open(f"{raw_location}/081616JHnew515Fcomplete-pr.fasta.otus.fa", 'r')
sequence_lines = [l.upper() for l in sequence_file.readlines()]
dna_lines = [DNA(str(seq), metadata=seq.metadata) for seq in skbio.io.read(sequence_lines, format='fasta')]
dna_lines_renamed = []

for seq in skbio.io.read(sequence_lines, format='fasta'):
    str_seq = str(seq)
    metadata = seq.metadata
    if (metadata['id'] in feature_metadata.index):
        metadata['id'] = metadata['id'] + "_" + feature_metadata.loc[metadata['id'], "Name"].replace(" ", "_").replace(".", "")
        dna_lines_renamed.append(DNA(str_seq, metadata=metadata))

# save
dna_lines_renamed_file = open(f"{raw_location}/renamed_081616JHnew515Fcomplete-pr.fasta.otus.fa", "w")
for seq in dna_lines_renamed:
    skbio.io.write(seq, into=dna_lines_renamed_file, format='fasta')

# %% [markdown]
# ### Import Newick Phylogenetic Tree

# %%
# import phylogenetic weights and use in an example
from skbio import TreeNode
tree_file = open(f"{raw_location}/MUSCLE_alignment_ML_tree_all_OTUs", "r")
tree = TreeNode.read(tree_file)
tree_rooted = tree.root_at_midpoint()
print(str(tree)[:50], "...")
# Out:
# (((((((((((((((((((((((((((((((((((((((OTU_199:0.0 ...

# %% [markdown]
# ## Alpha Diversity

# %%
# alpha diversity w/ phylogenetic weights example 
from skbio.diversity import alpha_diversity
# alpha_diversity(metric="faith_pd", counts=OTU_counts.T.values, ids=OTU_counts.columns, tree=tree_rooted, otu_ids=[n.name for n in tree_rooted.tips()], validate=True)

# %%
# ADD raw counts to sample meta data
sample_metadata["RC"] = OTU_counts.sum(axis = 0)
sample_metadata
# Out:
#          series     carbon  numerical_transfer transfer  day replicate  \
# sampleID
# sC0C        C0C   original                   0      C0C   10       C0C
# s1C03A        C  cellulose                   1       1C    3         A
# s1C03B        C  cellulose                   1       1C    3         B
# s1C05A        C  cellulose                   1       1C    5         A
# s1C05B        C  cellulose                   1       1C    5         B
# s1C07A        C  cellulose                   1       1C    7         A
# s1C07B        C  cellulose                   1       1C    7         B
# s1C10A        C  cellulose                   1       1C   10         A
# s1C10B        C  cellulose                   1       1C   10         B
# s1C20A        C  cellulose                   1       1C   20         A
# s1C20B        C  cellulose                   1       1C   20         B
# s2C03A        C  cellulose                   2       2C    3         A
# s2C03B        C  cellulose                   2       2C    3         B
# s2C05A        C  cellulose                   2       2C    5         A
# s2C05B        C  cellulose                   2       2C    5         B
# s2C10A        C  cellulose                   2       2C   10         A
# s2C10B        C  cellulose                   2       2C   10         B
# s1M03A        M     malate                   1       1M    3         A
# s1M03B        M     malate                   1       1M    3         B
# s1M03C        M     malate                   1       1M    3         C
# s1M05C        M     malate                   1       1M    5         C
# s1M05A        M     malate                   1       1M    5         A
# s1M05B        M     malate                   1       1M    5         B
# s1M07A        M     malate                   1       1M    7         A
# s1M07B        M     malate                   1       1M    7         B
# s1M07C        M     malate                   1       1M    7         C
# s1M10A        M     malate                   1       1M   10         A
# s1M10B        M     malate                   1       1M   10         B
# s1M10C        M     malate                   1       1M   10         C
# s2M03A        M  cellulose                   2       2M    3         A
# s2M03B        M  cellulose                   2       2M    3         B
# s2M03C        M  cellulose                   2       2M    3         C
# s2M05A        M  cellulose                   2       2M    5         A
# s2M05B        M  cellulose                   2       2M    5         B
# s2M07A        M  cellulose                   2       2M    7         A
# s2M07B        M  cellulose                   2       2M    7         B
# s2M10B        M  cellulose                   2       2M   10         B
# s2M10A        M  cellulose                   2       2M   10         A
# s2M10C        M  cellulose                   2       2M   10         C
# s3M03A        M  cellulose                   3       3M    3         A
# s3M03B        M  cellulose                   3       3M    3         B
# s3M03C        M  cellulose                   3       3M    3         C
# s3M05A        M  cellulose                   3       3M    5         A
# s3M05B        M  cellulose                   3       3M    5         B
# s3M05C        M  cellulose                   3       3M    5         C
# s3M07A        M  cellulose                   3       3M    7         A
# s3M07B        M  cellulose                   3       3M    7         B
# s3M07C        M  cellulose                   3       3M    7         C
# s3M10A        M  cellulose                   3       3M   10         A
# s3M10B        M  cellulose                   3       3M   10         B
# s3M10C        M  cellulose                   3       3M   10         C
# s1G03A        G    glucose                   1       1G    3         A
# s1G03B        G    glucose                   1       1G    3         B
# s1G03C        G    glucose                   1       1G    3         C
# s1G05A        G    glucose                   1       1G    5         A
# s1G05B        G    glucose                   1       1G    5         B
# s1G05C        G    glucose                   1       1G    5         C
# s1G07A        G    glucose                   1       1G    7         A
# s1G07B        G    glucose                   1       1G    7         B
# s1G07C        G    glucose                   1       1G    7         C
# s1G10A        G    glucose                   1       1G   10         A
# s1G10B        G    glucose                   1       1G   10         B
# s1G10C        G    glucose                   1       1G   10         C
# s2G03A        G  cellulose                   2       2G    3         A
# s2G03B        G  cellulose                   2       2G    3         B
# s2G03C        G  cellulose                   2       2G    3         C
# s2G05A        G  cellulose                   2       2G    5         A
# s2G05B        G  cellulose                   2       2G    5         B
# s2G05C        G  cellulose                   2       2G    5         C
# s2G07A        G  cellulose                   2       2G    7         A
# s2G07B        G  cellulose                   2       2G    7         B
# s2G07C        G  cellulose                   2       2G    7         C
# s2G10A        G  cellulose                   2       2G   10         A
# s2G10B        G  cellulose                   2       2G   10         B
# s2G10C        G  cellulose                   2       2G   10         C
# s3G03A        G  cellulose                   3       3G    3         A
# s3G03B        G  cellulose                   3       3G    3         B
# s3G03C        G  cellulose                   3       3G    3         C
# s3G05A        G  cellulose                   3       3G    5         A
# s3G05B        G  cellulose                   3       3G    5         B
# s3G05C        G  cellulose                   3       3G    5         C
# s3G07A        G  cellulose                   3       3G    7         A
# s3G07B        G  cellulose                   3       3G    7         B
# s3G07C        G  cellulose                   3       3G    7         C
# s3G10A        G  cellulose                   3       3G   10         A
# s3G10B        G  cellulose                   3       3G   10         B
#
#             cluster growth phase      RC
# sampleID
# sC0C           late     late C:C   88135
# s1C03A        early        early   72061
# s1C03B        early        early  117579
# s1C05A          mid      mid C:C   83646
# s1C05B        early        early  123739
# s1C07A          mid      mid C:C  111874
# s1C07B          mid      mid C:C  109082
# s1C10A         late     late C:C   75943
# s1C10B         late     late C:C   75413
# s1C20A         late     late C:C   66464
# s1C20B         late     late C:C   97148
# s2C03A          mid      mid C:C  122310
# s2C03B          mid      mid C:C  122881
# s2C05A          mid      mid C:C   42407
# s2C05B          mid      mid C:C  144202
# s2C10A         late     late C:C   98054
# s2C10B         late     late C:C  118057
# s1M03A    perturbed  perturbed M  108308
# s1M03B    perturbed  perturbed M  120785
# s1M03C    perturbed  perturbed M   77780
# s1M05C    perturbed  perturbed M  109191
# s1M05A    perturbed  perturbed M  115758
# s1M05B    perturbed  perturbed M  117938
# s1M07A    perturbed  perturbed M   39995
# s1M07B    perturbed  perturbed M   43061
# s1M07C    perturbed  perturbed M   73386
# s1M10A    perturbed  perturbed M  132348
# s1M10B    perturbed  perturbed M   95812
# s1M10C    perturbed  perturbed M  125381
# s2M03A        early        early  106765
# s2M03B        early        early  116427
# s2M03C        early        early   99306
# s2M05A        early        early  106415
# s2M05B        early        early  101681
# s2M07A          mid      mid M:C  114229
# s2M07B          mid      mid M:C  119237
# s2M10B          mid      mid M:C  111026
# s2M10A         late     late M:C  167494
# s2M10C         late     late M:C  125041
# s3M03A          mid      mid M:C   79215
# s3M03B          mid      mid M:C   79109
# s3M03C          mid      mid M:C   96576
# s3M05A         late     late M:C  159247
# s3M05B         late     late M:C  153462
# s3M05C         late     late M:C  106010
# s3M07A         late     late M:C  114291
# s3M07B         late     late M:C  133221
# s3M07C         late     late M:C  165495
# s3M10A         late     late M:C  153747
# s3M10B         late     late M:C  101763
# s3M10C         late     late M:C  137953
# s1G03A    perturbed  perturbed G  105194
# s1G03B    perturbed  perturbed G   73916
# s1G03C    perturbed  perturbed G  101822
# s1G05A    perturbed  perturbed G   94193
# s1G05B    perturbed  perturbed G   94213
# s1G05C    perturbed  perturbed G  101359
# s1G07A    perturbed  perturbed G   67431
# s1G07B    perturbed  perturbed G   73575
# s1G07C    perturbed  perturbed G   59814
# s1G10A    perturbed  perturbed G   39318
# s1G10B    perturbed  perturbed G   43594
# s1G10C    perturbed  perturbed G   75566
# s2G03A        early        early   93285
# s2G03B        early        early   94491
# s2G03C        early        early  122109
# s2G05A          mid      mid G:C  102671
# s2G05B          mid      mid G:C  125635
# s2G05C          mid      mid G:C  127890
# s2G07A         late     late G:C  127862
# s2G07B         late     late G:C  146096
# s2G07C         late     late G:C  149757
# s2G10A         late     late G:C  142404
# s2G10B         late     late G:C  115941
# s2G10C         late     late G:C   86261
# s3G03A          mid      mid G:C   72527
# s3G03B          mid      mid G:C   75288
# s3G03C          mid      mid G:C   93676
# s3G05A         late     late G:C   52916
# s3G05B         late     late G:C  109726
# s3G05C         late     late G:C  154636
# s3G07A         late     late G:C  177164
# s3G07B         late     late G:C  146638
# s3G07C         late     late G:C  153173
# s3G10A         late     late G:C  188359
# s3G10B         late     late G:C  134884

# %%
# ADD shdiv to sample meta data
shdiv = alpha_diversity(metric="shannon", ids=OTU_counts.columns, counts=OTU_counts.T.values) # default log base 2
sample_metadata["shdiv"] = shdiv
sample_metadata
# Out:
#          series     carbon  numerical_transfer transfer  day replicate  \
# sampleID
# sC0C        C0C   original                   0      C0C   10       C0C
# s1C03A        C  cellulose                   1       1C    3         A
# s1C03B        C  cellulose                   1       1C    3         B
# s1C05A        C  cellulose                   1       1C    5         A
# s1C05B        C  cellulose                   1       1C    5         B
# s1C07A        C  cellulose                   1       1C    7         A
# s1C07B        C  cellulose                   1       1C    7         B
# s1C10A        C  cellulose                   1       1C   10         A
# s1C10B        C  cellulose                   1       1C   10         B
# s1C20A        C  cellulose                   1       1C   20         A
# s1C20B        C  cellulose                   1       1C   20         B
# s2C03A        C  cellulose                   2       2C    3         A
# s2C03B        C  cellulose                   2       2C    3         B
# s2C05A        C  cellulose                   2       2C    5         A
# s2C05B        C  cellulose                   2       2C    5         B
# s2C10A        C  cellulose                   2       2C   10         A
# s2C10B        C  cellulose                   2       2C   10         B
# s1M03A        M     malate                   1       1M    3         A
# s1M03B        M     malate                   1       1M    3         B
# s1M03C        M     malate                   1       1M    3         C
# s1M05C        M     malate                   1       1M    5         C
# s1M05A        M     malate                   1       1M    5         A
# s1M05B        M     malate                   1       1M    5         B
# s1M07A        M     malate                   1       1M    7         A
# s1M07B        M     malate                   1       1M    7         B
# s1M07C        M     malate                   1       1M    7         C
# s1M10A        M     malate                   1       1M   10         A
# s1M10B        M     malate                   1       1M   10         B
# s1M10C        M     malate                   1       1M   10         C
# s2M03A        M  cellulose                   2       2M    3         A
# s2M03B        M  cellulose                   2       2M    3         B
# s2M03C        M  cellulose                   2       2M    3         C
# s2M05A        M  cellulose                   2       2M    5         A
# s2M05B        M  cellulose                   2       2M    5         B
# s2M07A        M  cellulose                   2       2M    7         A
# s2M07B        M  cellulose                   2       2M    7         B
# s2M10B        M  cellulose                   2       2M   10         B
# s2M10A        M  cellulose                   2       2M   10         A
# s2M10C        M  cellulose                   2       2M   10         C
# s3M03A        M  cellulose                   3       3M    3         A
# s3M03B        M  cellulose                   3       3M    3         B
# s3M03C        M  cellulose                   3       3M    3         C
# s3M05A        M  cellulose                   3       3M    5         A
# s3M05B        M  cellulose                   3       3M    5         B
# s3M05C        M  cellulose                   3       3M    5         C
# s3M07A        M  cellulose                   3       3M    7         A
# s3M07B        M  cellulose                   3       3M    7         B
# s3M07C        M  cellulose                   3       3M    7         C
# s3M10A        M  cellulose                   3       3M   10         A
# s3M10B        M  cellulose                   3       3M   10         B
# s3M10C        M  cellulose                   3       3M   10         C
# s1G03A        G    glucose                   1       1G    3         A
# s1G03B        G    glucose                   1       1G    3         B
# s1G03C        G    glucose                   1       1G    3         C
# s1G05A        G    glucose                   1       1G    5         A
# s1G05B        G    glucose                   1       1G    5         B
# s1G05C        G    glucose                   1       1G    5         C
# s1G07A        G    glucose                   1       1G    7         A
# s1G07B        G    glucose                   1       1G    7         B
# s1G07C        G    glucose                   1       1G    7         C
# s1G10A        G    glucose                   1       1G   10         A
# s1G10B        G    glucose                   1       1G   10         B
# s1G10C        G    glucose                   1       1G   10         C
# s2G03A        G  cellulose                   2       2G    3         A
# s2G03B        G  cellulose                   2       2G    3         B
# s2G03C        G  cellulose                   2       2G    3         C
# s2G05A        G  cellulose                   2       2G    5         A
# s2G05B        G  cellulose                   2       2G    5         B
# s2G05C        G  cellulose                   2       2G    5         C
# s2G07A        G  cellulose                   2       2G    7         A
# s2G07B        G  cellulose                   2       2G    7         B
# s2G07C        G  cellulose                   2       2G    7         C
# s2G10A        G  cellulose                   2       2G   10         A
# s2G10B        G  cellulose                   2       2G   10         B
# s2G10C        G  cellulose                   2       2G   10         C
# s3G03A        G  cellulose                   3       3G    3         A
# s3G03B        G  cellulose                   3       3G    3         B
# s3G03C        G  cellulose                   3       3G    3         C
# s3G05A        G  cellulose                   3       3G    5         A
# s3G05B        G  cellulose                   3       3G    5         B
# s3G05C        G  cellulose                   3       3G    5         C
# s3G07A        G  cellulose                   3       3G    7         A
# s3G07B        G  cellulose                   3       3G    7         B
# s3G07C        G  cellulose                   3       3G    7         C
# s3G10A        G  cellulose                   3       3G   10         A
# s3G10B        G  cellulose                   3       3G   10         B
#
#             cluster growth phase      RC     shdiv
# sampleID
# sC0C           late     late C:C   88135  3.799602
# s1C03A        early        early   72061  3.364793
# s1C03B        early        early  117579  3.236063
# s1C05A          mid      mid C:C   83646  3.346074
# s1C05B        early        early  123739  3.798067
# s1C07A          mid      mid C:C  111874  3.525643
# s1C07B          mid      mid C:C  109082  3.103721
# s1C10A         late     late C:C   75943  3.991071
# s1C10B         late     late C:C   75413  3.930440
# s1C20A         late     late C:C   66464  4.044168
# s1C20B         late     late C:C   97148  3.830726
# s2C03A          mid      mid C:C  122310  3.134946
# s2C03B          mid      mid C:C  122881  2.928747
# s2C05A          mid      mid C:C   42407  3.507209
# s2C05B          mid      mid C:C  144202  3.553612
# s2C10A         late     late C:C   98054  3.478361
# s2C10B         late     late C:C  118057  3.131049
# s1M03A    perturbed  perturbed M  108308  1.675195
# s1M03B    perturbed  perturbed M  120785  1.722220
# s1M03C    perturbed  perturbed M   77780  1.850731
# s1M05C    perturbed  perturbed M  109191  1.160373
# s1M05A    perturbed  perturbed M  115758  1.293326
# s1M05B    perturbed  perturbed M  117938  1.277928
# s1M07A    perturbed  perturbed M   39995  1.356451
# s1M07B    perturbed  perturbed M   43061  1.145209
# s1M07C    perturbed  perturbed M   73386  1.395012
# s1M10A    perturbed  perturbed M  132348  2.037897
# s1M10B    perturbed  perturbed M   95812  2.150086
# s1M10C    perturbed  perturbed M  125381  1.935009
# s2M03A        early        early  106765  2.579041
# s2M03B        early        early  116427  3.047760
# s2M03C        early        early   99306  2.951382
# s2M05A        early        early  106415  3.064663
# s2M05B        early        early  101681  3.173228
# s2M07A          mid      mid M:C  114229  3.494358
# s2M07B          mid      mid M:C  119237  3.338071
# s2M10B          mid      mid M:C  111026  3.281789
# s2M10A         late     late M:C  167494  3.637787
# s2M10C         late     late M:C  125041  2.921264
# s3M03A          mid      mid M:C   79215  2.162134
# s3M03B          mid      mid M:C   79109  2.840548
# s3M03C          mid      mid M:C   96576  2.436913
# s3M05A         late     late M:C  159247  3.232959
# s3M05B         late     late M:C  153462  3.659657
# s3M05C         late     late M:C  106010  3.135078
# s3M07A         late     late M:C  114291  3.572565
# s3M07B         late     late M:C  133221  3.689604
# s3M07C         late     late M:C  165495  3.761164
# s3M10A         late     late M:C  153747  3.925015
# s3M10B         late     late M:C  101763  3.525214
# s3M10C         late     late M:C  137953  3.560605
# s1G03A    perturbed  perturbed G  105194  3.186670
# s1G03B    perturbed  perturbed G   73916  3.073363
# s1G03C    perturbed  perturbed G  101822  3.110048
# s1G05A    perturbed  perturbed G   94193  1.980996
# s1G05B    perturbed  perturbed G   94213  2.214885
# s1G05C    perturbed  perturbed G  101359  2.236659
# s1G07A    perturbed  perturbed G   67431  2.570959
# s1G07B    perturbed  perturbed G   73575  2.521910
# s1G07C    perturbed  perturbed G   59814  2.204515
# s1G10A    perturbed  perturbed G   39318  3.055165
# s1G10B    perturbed  perturbed G   43594  3.102649
# s1G10C    perturbed  perturbed G   75566  3.151104
# s2G03A        early        early   93285  3.036323
# s2G03B        early        early   94491  2.969395
# s2G03C        early        early  122109  3.112095
# s2G05A          mid      mid G:C  102671  2.972371
# s2G05B          mid      mid G:C  125635  3.067717
# s2G05C          mid      mid G:C  127890  3.055017
# s2G07A         late     late G:C  127862  3.503990
# s2G07B         late     late G:C  146096  3.479947
# s2G07C         late     late G:C  149757  3.481596
# s2G10A         late     late G:C  142404  3.466162
# s2G10B         late     late G:C  115941  3.666566
# s2G10C         late     late G:C   86261  3.554995
# s3G03A          mid      mid G:C   72527  2.534178
# s3G03B          mid      mid G:C   75288  2.391599
# s3G03C          mid      mid G:C   93676  2.294888
# s3G05A         late     late G:C   52916  3.433136
# s3G05B         late     late G:C  109726  3.490660
# s3G05C         late     late G:C  154636  3.448893
# s3G07A         late     late G:C  177164  3.211457
# s3G07B         late     late G:C  146638  3.295120
# s3G07C         late     late G:C  153173  3.407462
# s3G10A         late     late G:C  188359  3.289271
# s3G10B         late     late G:C  134884  3.267083

# %% [markdown]
# # Save

# %%
# save OTU counts
OTU_counts.to_csv(f"{raw_location}/processed_OTU_counts.tsv", sep='\t')
# save sample metadata
sample_metadata.to_csv(f"{raw_location}/processed_sample_metadata.tsv", sep='\t')
# save OTU taxonomy
feature_metadata.to_csv(f"{raw_location}/processed_feature_metadata.tsv", sep='\t')
feature_metadata["taxonomy"].to_csv(f"{raw_location}/processed_taxonomy.tsv", sep='\t')
feature_metadata[["kingdom", "phylum", "class", "order", "family", "genus", "species"]].to_csv(f"{raw_location}/processed_taxonomy_table.tsv", sep='\t')
